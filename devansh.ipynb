# %%
print("hello, world")
# Out:
# hello, world

# %%
print("hello patel");print("hello devansh")
# Out:
# hello patel
# hello devansh

# %%
## syntax error
print("hello patel") print("hello devansh")
# Out:
#   Cell In[4], line 2
#     print("hello patel") print("hello devansh")
#                          ^
# SyntaxError: invalid syntax

# %%
print("1.hello i am devansh patel",end="  2.")
print("i am 20 year old brother")
# Out:
# 1.hello i am devansh patel  2.i am 20 year old brother

# %%
print(5)
print(5+5)
print(5-2)
print(5*2)
print(5%2)
print(5//2)
print("hello i am devansh. i am",20,"years old")
# Out:
# 5
# 10
# 3
# 10
# 1
# 2
# hello i am devansh. i am 20 years old

# %%
x=5
y=10
print(x+y)
x=int(3.0)
print(x)
x=float(5)
print(x)
x=str(3)
print(x)
# Out:
# 15
# 3
# 5.0
# 3

# %%
x,y,z="devansh","babubhai","patel"
print(x,y,z)
# Out:
# devansh babubhai patel
